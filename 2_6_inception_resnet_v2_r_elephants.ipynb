# %%
import tensorflow as tf
import numpy as np
import os,pathlib

# %%
#方法定义 #get_r_list做了较多关键修改

def preprocess_data(dataset):
    all_images = []
    all_labels = []
    for image,label in dataset:
        preprocessed_image = tf.keras.applications.inception_resnet_v2.preprocess_input(image)
        all_images.append(preprocessed_image)
        all_labels.append(label)
    return np.concatenate(all_images),np.concatenate(all_labels)

def get_r_list():
    index_r_list = []
    name_r_list = []
    for i,layer in enumerate(base_model.layers):
        if layer.name[0:5] == 'mixed' or layer.name[-4:] == '5_ac':
            index_r_list.append(i)
            name_r_list.append(layer.name)
    r_list = [0]
    for i in index_r_list:
        r = i/len(base_model.layers)
        r_list.append(r)
    return r_list

def build_model():
    x = conv_base.output
    predictions = classifier(x)
    model = tf.keras.Model(inputs=conv_base.input,outputs=predictions)
    return model

def r_compiled_model():
    model = build_model()
    for layer in model.layers[:int(r*len(conv_base.layers))+1]:
        layer.trainable = False
    for layer in model.layers[int(r*len(conv_base.layers))+1:]:
        layer.trainable = True
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001,momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#加载数据、预处理数据

base_dir = pathlib.Path('elephants')
train_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'train',
                                                            image_size=(224,224),
                                                            batch_size=32)
validation_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'val',
                                                                 image_size=(224,224),
                                                                 batch_size=32)
train_images,train_labels = preprocess_data(train_dataset)
val_images,val_labels = preprocess_data(validation_dataset)
# Out:
# Found 240 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %%
#分类器初训练

base_model = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(weights='imagenet',include_top=False)

inputs = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
x = tf.keras.layers.Dense(units=256,activation='relu')(x)
outputs = tf.keras.layers.Dense(units=1,activation='sigmoid')(x)
classifier_model = tf.keras.Model(inputs=inputs,outputs=outputs)

x = base_model.output
predictions = classifier_model(x)
model = tf.keras.Model(inputs=base_model.input,outputs=predictions)

for layer in model.layers[:len(base_model.layers)]:
    layer.trainable = False
    
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
callback_list = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath='inceptionresnetv2_r_1.00.keras',
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
history = model.fit(train_images,train_labels,
                    epochs=15,
                    validation_data=(val_images,val_labels),
                    callbacks=callback_list)
r_1_acc = max(history.history['val_accuracy'])
print(r_1_acc)
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020585C7ED08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020585C7ED08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 1.5765 - accuracy: 0.5875WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020585C7E158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020585C7E158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 40s 4s/step - loss: 1.5765 - accuracy: 0.5875 - val_loss: 0.6104 - val_accuracy: 0.6150
# Epoch 2/15
# 8/8 [==============================] - 30s 4s/step - loss: 0.6138 - accuracy: 0.6750 - val_loss: 0.4394 - val_accuracy: 0.8550
# Epoch 3/15
# 8/8 [==============================] - 30s 4s/step - loss: 0.5580 - accuracy: 0.7250 - val_loss: 0.5997 - val_accuracy: 0.6900
# Epoch 4/15
# 8/8 [==============================] - 30s 4s/step - loss: 0.5378 - accuracy: 0.7250 - val_loss: 0.4320 - val_accuracy: 0.8100
# 0.8550000190734863

# %%
#搜索最佳迁移率R(验证理论)

classifier_p = model.get_layer(model.layers[-1].name)
r_list = get_r_list()
best_acc = r_1_acc
r_acc = []

for i in range(len(r_list)):
    r = r_list[i]
    conv_base = tf.keras.applications.inception_resnet_v2.InceptionResNetV2(weights='imagenet',include_top=False)
    classifier = classifier_p
    model = r_compiled_model()
    filepath = 'inceptionresnetv2_r_{:.2f}.keras'.format(r)
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath=filepath,
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
    history = model.fit(train_images,train_labels,
                        epochs=15,
                        validation_data=(val_images,val_labels),
                        callbacks=callbacks)
    r_acc.append(max(history.history['val_accuracy']))
    
    if i == 0 and r_acc[0] < r_1_acc:
        r_list = r_list[:1]+r_list[:0:-1]
        continue
    if r_acc[i] > best_acc:
        best_acc = r_acc[i]
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002058BD1F048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002058BD1F048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6418 - accuracy: 0.6208 WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002058B726D08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002058B726D08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 123s 14s/step - loss: 0.6418 - accuracy: 0.6208 - val_loss: 0.4274 - val_accuracy: 0.8150
# Epoch 2/15
# 8/8 [==============================] - 106s 13s/step - loss: 0.6462 - accuracy: 0.6250 - val_loss: 0.4272 - val_accuracy: 0.8200
# Epoch 3/15
# 8/8 [==============================] - 105s 13s/step - loss: 0.6338 - accuracy: 0.6167 - val_loss: 0.4264 - val_accuracy: 0.8300
# Epoch 4/15
# 8/8 [==============================] - 110s 14s/step - loss: 0.6376 - accuracy: 0.6292 - val_loss: 0.4280 - val_accuracy: 0.8200
# Epoch 5/15
# 8/8 [==============================] - 106s 13s/step - loss: 0.6332 - accuracy: 0.6250 - val_loss: 0.4295 - val_accuracy: 0.8250
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BE4C3158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BE4C3158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.7292WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000205BA41EAE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000205BA41EAE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 45s 5s/step - loss: 0.5821 - accuracy: 0.7292 - val_loss: 0.4494 - val_accuracy: 0.7850
# Epoch 2/15
# 8/8 [==============================] - 36s 5s/step - loss: 0.5798 - accuracy: 0.7375 - val_loss: 0.4523 - val_accuracy: 0.7800
# Epoch 3/15
# 8/8 [==============================] - 35s 5s/step - loss: 0.5784 - accuracy: 0.7500 - val_loss: 0.4540 - val_accuracy: 0.7800
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020586B74158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020586B74158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.7375WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000205B1F5DA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000205B1F5DA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 52s 6s/step - loss: 0.5863 - accuracy: 0.7375 - val_loss: 0.4504 - val_accuracy: 0.7850
# Epoch 2/15
# 8/8 [==============================] - 39s 5s/step - loss: 0.5891 - accuracy: 0.7375 - val_loss: 0.4497 - val_accuracy: 0.7900
# Epoch 3/15
# 8/8 [==============================] - 39s 5s/step - loss: 0.5831 - accuracy: 0.7333 - val_loss: 0.4460 - val_accuracy: 0.7950
# Epoch 4/15
# 8/8 [==============================] - 39s 5s/step - loss: 0.5795 - accuracy: 0.7458 - val_loss: 0.4413 - val_accuracy: 0.8050
# Epoch 5/15
# 8/8 [==============================] - 38s 5s/step - loss: 0.5762 - accuracy: 0.7625 - val_loss: 0.4382 - val_accuracy: 0.8000
# Epoch 6/15
# 8/8 [==============================] - 39s 5s/step - loss: 0.5731 - accuracy: 0.7417 - val_loss: 0.4330 - val_accuracy: 0.8100
# Epoch 7/15
# 8/8 [==============================] - 38s 5s/step - loss: 0.5627 - accuracy: 0.7542 - val_loss: 0.4276 - val_accuracy: 0.8100
# Epoch 8/15
# 8/8 [==============================] - 38s 5s/step - loss: 0.5649 - accuracy: 0.7375 - val_loss: 0.4225 - val_accuracy: 0.8100
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BBDDD488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BBDDD488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.6875WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002058BD1F8C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002058BD1F8C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 65s 7s/step - loss: 0.6080 - accuracy: 0.6875 - val_loss: 0.4455 - val_accuracy: 0.7900
# Epoch 2/15
# 8/8 [==============================] - 50s 6s/step - loss: 0.6085 - accuracy: 0.7125 - val_loss: 0.4439 - val_accuracy: 0.7900
# Epoch 3/15
# 8/8 [==============================] - 50s 7s/step - loss: 0.6044 - accuracy: 0.7042 - val_loss: 0.4414 - val_accuracy: 0.8000
# Epoch 4/15
# 8/8 [==============================] - 50s 7s/step - loss: 0.6003 - accuracy: 0.7458 - val_loss: 0.4380 - val_accuracy: 0.8150
# Epoch 5/15
# 8/8 [==============================] - 51s 7s/step - loss: 0.5936 - accuracy: 0.7250 - val_loss: 0.4360 - val_accuracy: 0.8100
# Epoch 6/15
# 8/8 [==============================] - 51s 7s/step - loss: 0.5857 - accuracy: 0.7417 - val_loss: 0.4348 - val_accuracy: 0.8100
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BC5E8400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205BC5E8400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.6375WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020586B74488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020586B74488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 97s 11s/step - loss: 0.6326 - accuracy: 0.6375 - val_loss: 0.4497 - val_accuracy: 0.7950
# Epoch 2/15
# 8/8 [==============================] - 93s 12s/step - loss: 0.6265 - accuracy: 0.6750 - val_loss: 0.4457 - val_accuracy: 0.8000
# Epoch 3/15
# 8/8 [==============================] - 92s 12s/step - loss: 0.6267 - accuracy: 0.6250 - val_loss: 0.4411 - val_accuracy: 0.8050
# Epoch 4/15
# 8/8 [==============================] - 92s 12s/step - loss: 0.6214 - accuracy: 0.6708 - val_loss: 0.4378 - val_accuracy: 0.8000
# Epoch 5/15
# 8/8 [==============================] - 92s 12s/step - loss: 0.6106 - accuracy: 0.7083 - val_loss: 0.4355 - val_accuracy: 0.7900
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205B0A0F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205B0A0F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6369 - accuracy: 0.6458 WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020586B74950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020586B74950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 115s 13s/step - loss: 0.6369 - accuracy: 0.6458 - val_loss: 0.4534 - val_accuracy: 0.7900
# Epoch 2/15
# 8/8 [==============================] - 100s 13s/step - loss: 0.6327 - accuracy: 0.6542 - val_loss: 0.4476 - val_accuracy: 0.8000
# Epoch 3/15
# 8/8 [==============================] - 98s 13s/step - loss: 0.6290 - accuracy: 0.6125 - val_loss: 0.4424 - val_accuracy: 0.8000
# Epoch 4/15
# 8/8 [==============================] - 100s 13s/step - loss: 0.6415 - accuracy: 0.6500 - val_loss: 0.4386 - val_accuracy: 0.8050
# Epoch 5/15
# 8/8 [==============================] - 98s 13s/step - loss: 0.6222 - accuracy: 0.6708 - val_loss: 0.4329 - val_accuracy: 0.8050
# Epoch 6/15
# 8/8 [==============================] - 100s 13s/step - loss: 0.6251 - accuracy: 0.6750 - val_loss: 0.4283 - val_accuracy: 0.8150
# Epoch 7/15
# 8/8 [==============================] - 98s 13s/step - loss: 0.6162 - accuracy: 0.6917 - val_loss: 0.4235 - val_accuracy: 0.8100
# Epoch 8/15
# 8/8 [==============================] - 99s 13s/step - loss: 0.6063 - accuracy: 0.6708 - val_loss: 0.4215 - val_accuracy: 0.8250
# Epoch 9/15
# 8/8 [==============================] - 100s 13s/step - loss: 0.6068 - accuracy: 0.6875 - val_loss: 0.4216 - val_accuracy: 0.8350
# Epoch 10/15
# 8/8 [==============================] - 98s 13s/step - loss: 0.5996 - accuracy: 0.7292 - val_loss: 0.4250 - val_accuracy: 0.8350
# Epoch 11/15
# 8/8 [==============================] - 98s 13s/step - loss: 0.5947 - accuracy: 0.7250 - val_loss: 0.4309 - val_accuracy: 0.8250
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205B0B7E950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000205B0B7E950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.6250 WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020588E09D08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020588E09D08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 131s 15s/step - loss: 0.6385 - accuracy: 0.6250 - val_loss: 0.4531 - val_accuracy: 0.7900
# Epoch 2/15
# 8/8 [==============================] - 117s 15s/step - loss: 0.6310 - accuracy: 0.6500 - val_loss: 0.4458 - val_accuracy: 0.8000
# Epoch 3/15
# 8/8 [==============================] - 115s 15s/step - loss: 0.6265 - accuracy: 0.6167 - val_loss: 0.4428 - val_accuracy: 0.8100
# Epoch 4/15
# 8/8 [==============================] - 114s 15s/step - loss: 0.6162 - accuracy: 0.6792 - val_loss: 0.4401 - val_accuracy: 0.8200
# Epoch 5/15
# 8/8 [==============================] - 115s 15s/step - loss: 0.6176 - accuracy: 0.6625 - val_loss: 0.4384 - val_accuracy: 0.8100
# Epoch 6/15
# 8/8 [==============================] - 113s 14s/step - loss: 0.6148 - accuracy: 0.7000 - val_loss: 0.4382 - val_accuracy: 0.8150
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002063E1781E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002063E1781E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.6792 WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002063E195598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002063E195598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 146s 17s/step - loss: 0.6280 - accuracy: 0.6792 - val_loss: 0.4578 - val_accuracy: 0.8000
# Epoch 2/15
# 8/8 [==============================] - 135s 17s/step - loss: 0.6351 - accuracy: 0.6500 - val_loss: 0.4507 - val_accuracy: 0.8050
# Epoch 3/15
# 8/8 [==============================] - 134s 17s/step - loss: 0.6234 - accuracy: 0.6667 - val_loss: 0.4457 - val_accuracy: 0.8150
# Epoch 4/15
# 8/8 [==============================] - 134s 17s/step - loss: 0.6269 - accuracy: 0.6625 - val_loss: 0.4444 - val_accuracy: 0.8050
# Epoch 5/15
# 8/8 [==============================] - 134s 17s/step - loss: 0.6110 - accuracy: 0.7042 - val_loss: 0.4433 - val_accuracy: 0.8050

# %%
#观察结果

print(r_list)
print(r_acc)
# Out:
# [0, 0.8935897435897436, 0.791025641025641, 0.658974358974359, 0.45384615384615384, 0.35128205128205126, 0.19230769230769232, 0.05128205128205128]
# [0.8299999833106995, 0.7850000262260437, 0.8100000023841858, 0.8149999976158142, 0.8050000071525574, 0.8349999785423279, 0.8199999928474426, 0.8149999976158142]

# %%
##整理结果

r_list.pop(0)
r_0_acc = r_acc.pop(0)

r_list.append(0)
r_acc.append(r_0_acc)

r_list.insert(0,1)
r_acc.insert(0,r_1_acc)
print(r_list)
print(r_acc)
# Out:
# [1, 0.8935897435897436, 0.791025641025641, 0.658974358974359, 0.45384615384615384, 0.35128205128205126, 0.19230769230769232, 0.05128205128205128, 0]
# [0.8550000190734863, 0.7850000262260437, 0.8100000023841858, 0.8149999976158142, 0.8050000071525574, 0.8349999785423279, 0.8199999928474426, 0.8149999976158142, 0.8299999833106995]

# %%
#展示结果

import matplotlib.pyplot as plt
plt.figure()
plt.plot(r_list,r_acc,linestyle='-',marker='o',color='m',label='inception_resnet_v2')
plt.xlabel('transfer rate')
plt.ylabel('accuracy')
plt.ylim((0.5,1))

plt.title('Validation accuracy')
plt.legend()
plt.show()
