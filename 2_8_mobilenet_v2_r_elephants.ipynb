# %%
import tensorflow as tf
import numpy as np
import os,pathlib

# %%
#方法定义 #get_r_list做了较多关键修改

def preprocess_data(dataset):
    all_images = []
    all_labels = []
    for image,label in dataset:
        preprocessed_image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
        all_images.append(preprocessed_image)
        all_labels.append(label)
    return np.concatenate(all_images),np.concatenate(all_labels)

def get_r_list():
    index_r_list = []
    name_r_list = []
    for i,layer in enumerate(base_model.layers):
        if layer.name[-3:] == 'add':
            index_r_list.append(i)
            name_r_list.append(layer.name)
    r_list = [0]
    for i in index_r_list:
        r = i/len(base_model.layers)
        r_list.append(r)
    return r_list

def build_model():
    x = conv_base.output
    predictions = classifier(x)
    model = tf.keras.Model(inputs=conv_base.input,outputs=predictions)
    return model

def r_compiled_model():
    model = build_model()
    for layer in model.layers[:int(r*len(conv_base.layers))+1]:
        layer.trainable = False
    for layer in model.layers[int(r*len(conv_base.layers))+1:]:
        layer.trainable = True
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001,momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#加载数据、预处理数据

base_dir = pathlib.Path('elephants')
train_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'train',
                                                            image_size=(224,224),
                                                            batch_size=32)
validation_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'val',
                                                                 image_size=(224,224),
                                                                 batch_size=32)
train_images,train_labels = preprocess_data(train_dataset)
val_images,val_labels = preprocess_data(validation_dataset)
# Out:
# Found 240 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %%
#分类器初训练

base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(weights='imagenet',include_top=False)

inputs = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
x = tf.keras.layers.Dense(units=256,activation='relu')(x)
outputs = tf.keras.layers.Dense(units=1,activation='sigmoid')(x)
classifier_model = tf.keras.Model(inputs=inputs,outputs=outputs)

x = base_model.output
predictions = classifier_model(x)
model = tf.keras.Model(inputs=base_model.input,outputs=predictions)

for layer in model.layers[:len(base_model.layers)]:
    layer.trainable = False
    
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
callback_list = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath='mobilenet_v2_r_1.00.keras',
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
history = model.fit(train_images,train_labels,
                    epochs=15,
                    validation_data=(val_images,val_labels),
                    callbacks=callback_list)
r_1_acc = max(history.history['val_accuracy'])
print(r_1_acc)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C890F5400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C890F5400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 1.0234 - accuracy: 0.6333WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8ACE0158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8ACE0158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 11s 1s/step - loss: 1.0234 - accuracy: 0.6333 - val_loss: 0.5937 - val_accuracy: 0.7200
# Epoch 2/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.5461 - accuracy: 0.6875 - val_loss: 0.4249 - val_accuracy: 0.8300
# Epoch 3/15
# 8/8 [==============================] - 7s 930ms/step - loss: 0.4961 - accuracy: 0.7500 - val_loss: 0.4966 - val_accuracy: 0.7800
# Epoch 4/15
# 8/8 [==============================] - 7s 942ms/step - loss: 0.3928 - accuracy: 0.8083 - val_loss: 0.4587 - val_accuracy: 0.8000
# 0.8299999833106995

# %%
#搜索最佳迁移率R(验证理论)

classifier_p = model.get_layer(model.layers[-1].name)
r_list = get_r_list()
best_acc = r_1_acc
r_acc = []

for i in range(len(r_list)):
    r = r_list[i]
    conv_base = tf.keras.applications.mobilenet_v2.MobileNetV2(weights='imagenet',include_top=False)
    classifier = classifier_p
    model = r_compiled_model()
    filepath = 'mobilenet_v2_r_{:.2f}.keras'.format(r)
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath=filepath,
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
    history = model.fit(train_images,train_labels,
                        epochs=15,
                        validation_data=(val_images,val_labels),
                        callbacks=callbacks)
    r_acc.append(max(history.history['val_accuracy']))
    
    if i == 0 and r_acc[0] < r_1_acc:
        r_list = r_list[:1]+r_list[:0:-1]
        continue
    if r_acc[i] > best_acc:
        best_acc = r_acc[i]
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C8B26F158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C8B26F158> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 1.0294 - accuracy: 0.5250WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8C0A4AE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8C0A4AE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 33s 4s/step - loss: 1.0294 - accuracy: 0.5250 - val_loss: 0.4604 - val_accuracy: 0.7900
# Epoch 2/15
# 8/8 [==============================] - 27s 3s/step - loss: 0.8914 - accuracy: 0.5500 - val_loss: 0.4687 - val_accuracy: 0.7900
# Epoch 3/15
# 8/8 [==============================] - 26s 3s/step - loss: 0.7385 - accuracy: 0.6000 - val_loss: 0.4775 - val_accuracy: 0.7900
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C8B9D61E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C8B9D61E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.6215 - accuracy: 0.6917WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8EF56488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8EF56488> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 10s 1s/step - loss: 0.6215 - accuracy: 0.6917 - val_loss: 0.5158 - val_accuracy: 0.7650
# Epoch 2/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.5682 - accuracy: 0.7208 - val_loss: 0.5115 - val_accuracy: 0.7700
# Epoch 3/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.4996 - accuracy: 0.7333 - val_loss: 0.5059 - val_accuracy: 0.7750
# Epoch 4/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.4381 - accuracy: 0.7542 - val_loss: 0.4995 - val_accuracy: 0.7800
# Epoch 5/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3921 - accuracy: 0.8208 - val_loss: 0.4934 - val_accuracy: 0.7750
# Epoch 6/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3918 - accuracy: 0.7958 - val_loss: 0.4866 - val_accuracy: 0.7850
# Epoch 7/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3628 - accuracy: 0.8500 - val_loss: 0.4770 - val_accuracy: 0.7950
# Epoch 8/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3367 - accuracy: 0.8542 - val_loss: 0.4716 - val_accuracy: 0.8000
# Epoch 9/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3366 - accuracy: 0.8625 - val_loss: 0.4675 - val_accuracy: 0.8000
# Epoch 10/15
# 8/8 [==============================] - 7s 973ms/step - loss: 0.3263 - accuracy: 0.8792 - val_loss: 0.4632 - val_accuracy: 0.7950
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C947BAE18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C947BAE18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.4531 - accuracy: 0.8000WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8B4AA378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8B4AA378> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 11s 1s/step - loss: 0.4531 - accuracy: 0.8000 - val_loss: 0.6552 - val_accuracy: 0.6650
# Epoch 2/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.4564 - accuracy: 0.7792 - val_loss: 0.6545 - val_accuracy: 0.6600
# Epoch 3/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.4187 - accuracy: 0.8083 - val_loss: 0.6491 - val_accuracy: 0.6700
# Epoch 4/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3978 - accuracy: 0.8167 - val_loss: 0.6448 - val_accuracy: 0.6700
# Epoch 5/15
# 8/8 [==============================] - 8s 1s/step - loss: 0.3984 - accuracy: 0.8042 - val_loss: 0.6400 - val_accuracy: 0.6700
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020C
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020CA863ED90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020CA863ED90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.7458WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8BA54C80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020C8BA54C80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 20s 2s/step - loss: 0.5299 - accuracy: 0.7458 - val_loss: 0.7308 - val_accuracy: 0.6450
# Epoch 2/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.4886 - accuracy: 0.7583 - val_loss: 0.7208 - val_accuracy: 0.6450
# Epoch 3/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.4651 - accuracy: 0.7542 - val_loss: 0.7047 - val_accuracy: 0.6500
# Epoch 4/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.4424 - accuracy: 0.8208 - val_loss: 0.6940 - val_accuracy: 0.6500
# Epoch 5/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.4119 - accuracy: 0.8375 - val_loss: 0.6789 - val_accuracy: 0.6550
# Epoch 6/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.3822 - accuracy: 0.8458 - val_loss: 0.6646 - val_accuracy: 0.6600
# Epoch 7/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.3578 - accuracy: 0.8875 - val_loss: 0.6518 - val_accuracy: 0.6700
# Epoch 8/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.3347 - accuracy: 0.8958 - val_loss: 0.6403 - val_accuracy: 0.6700
# Epoch 9/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.2958 - accuracy: 0.9250 - val_loss: 0.6298 - val_accuracy: 0.6750
# Epoch 10/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.2949 - accuracy: 0.9250 - val_loss: 0.6243 - val_accuracy: 0.6850
# Epoch 11/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.2818 - accuracy: 0.9292 - val_loss: 0.6194 - val_accuracy: 0.6900
# Epoch 12/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.2659 - accuracy: 0.9375 - val_loss: 0.6173 - val_accuracy: 0.6800
# Epoch 13/15
# 8/8 [==============================] - 16s 2s/step - loss: 0.2491 - accuracy: 0.9500 - val_loss: 0.6108 - val_accuracy: 0.6850

# %%
#观察结果

print(r_list)
print(r_acc)
# Out:
# [0, 0.922077922077922, 0.8636363636363636, 0.7467532467532467, 0.6883116883116883, 0.577922077922078, 0.5194805194805194, 0.461038961038961, 0.34415584415584416, 0.2857142857142857, 0.16883116883116883]
# [0.7900000214576721, 0.800000011920929, 0.6700000166893005, 0.6449999809265137, 0.6650000214576721, 0.6399999856948853, 0.6600000262260437, 0.6549999713897705, 0.6499999761581421, 0.6499999761581421, 0.6899999976158142]

# %%
##整理结果

r_list.pop(0)
r_0_acc = r_acc.pop(0)

r_list.append(0)
r_acc.append(r_0_acc)

r_list.insert(0,1)
r_acc.insert(0,r_1_acc)
print(r_list)
print(r_acc)
# Out:
# [1, 0.922077922077922, 0.8636363636363636, 0.7467532467532467, 0.6883116883116883, 0.577922077922078, 0.5194805194805194, 0.461038961038961, 0.34415584415584416, 0.2857142857142857, 0.16883116883116883, 0]
# [0.8299999833106995, 0.800000011920929, 0.6700000166893005, 0.6449999809265137, 0.6650000214576721, 0.6399999856948853, 0.6600000262260437, 0.6549999713897705, 0.6499999761581421, 0.6499999761581421, 0.6899999976158142, 0.7900000214576721]

# %%
#展示结果

import matplotlib.pyplot as plt
plt.figure()
plt.plot(r_list,r_acc,linestyle='-',marker='o',color='r',label='mobilenet_v2')
plt.xlabel('transfer rate')
plt.ylabel('accuracy')
plt.ylim((0.5,1))

plt.title('Validation accuracy')
plt.legend()
plt.show()
