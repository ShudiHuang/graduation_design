# %%
import tensorflow as tf
import numpy as np
import os,pathlib

# %%
#方法定义 #get_r_list做了关键修改

def preprocess_data(dataset):
    all_images = []
    all_labels = []
    for image,label in dataset:
        preprocessed_image = tf.keras.applications.resnet50.preprocess_input(image)
        all_images.append(preprocessed_image)
        all_labels.append(label)
    return np.concatenate(all_images),np.concatenate(all_labels)

def get_r_list():
    index_out_list = []
    name_out_list = []
    for i,layer in enumerate(base_model.layers):
        if layer.name[-3:] == 'out':
            index_out_list.append(i)
            name_out_list.append(layer.name)
    index_r_list = []
    name_r_list = []
    for j in range(len(name_out_list)-1):
        if name_out_list[j][0:5] != name_out_list[j+1][0:5]:
            index_r_list.append(index_out_list[j])
            name_r_list.append(name_out_list[j])
    r_list = [0]
    for i in index_r_list:
        r = i/len(base_model.layers)
        r_list.append(r)
    return r_list

def build_model():
    x = conv_base.output
    predictions = classifier(x)
    model = tf.keras.Model(inputs=conv_base.input,outputs=predictions)
    return model

def r_compiled_model():
    model = build_model()
    for layer in model.layers[:int(r*len(conv_base.layers))+1]:
        layer.trainable = False
    for layer in model.layers[int(r*len(conv_base.layers))+1:]:
        layer.trainable = True
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001,momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#加载数据、预处理数据

base_dir = pathlib.Path('elephants')
train_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'train',
                                                            image_size=(224,224),
                                                            batch_size=32)
validation_dataset = tf.keras.utils.image_dataset_from_directory(base_dir/'val',
                                                                 image_size=(224,224),
                                                                 batch_size=32)
train_images,train_labels = preprocess_data(train_dataset)
val_images,val_labels = preprocess_data(validation_dataset)
# Out:
# Found 240 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %%
#分类器初训练

base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet',include_top=False)

inputs = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
x = tf.keras.layers.Dense(units=256,activation='relu')(x)
outputs = tf.keras.layers.Dense(units=1,activation='sigmoid')(x)
classifier_model = tf.keras.Model(inputs=inputs,outputs=outputs)

x = base_model.output
predictions = classifier_model(x)
model = tf.keras.Model(inputs=base_model.input,outputs=predictions)

for layer in model.layers[:len(base_model.layers)]:
    layer.trainable = False
    
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
callback_list = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath='resnet50_r_1.00.keras',
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
history = model.fit(train_images,train_labels,
                    epochs=15,
                    validation_data=(val_images,val_labels),
                    callbacks=callback_list)
r_1_acc = max(history.history['val_accuracy'])
print(r_1_acc)
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620EDAE6A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620EDAE6A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 1.9674 - accuracy: 0.5875WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620FD22840> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620FD22840> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 27s 3s/step - loss: 1.9674 - accuracy: 0.5875 - val_loss: 0.9735 - val_accuracy: 0.5000
# Epoch 2/15
# 8/8 [==============================] - 25s 3s/step - loss: 0.6492 - accuracy: 0.6500 - val_loss: 0.6641 - val_accuracy: 0.6000
# Epoch 3/15
# 8/8 [==============================] - 24s 3s/step - loss: 0.5374 - accuracy: 0.7208 - val_loss: 0.7202 - val_accuracy: 0.5850
# Epoch 4/15
# 8/8 [==============================] - 25s 3s/step - loss: 0.5184 - accuracy: 0.7375 - val_loss: 0.4849 - val_accuracy: 0.7700
# Epoch 5/15
# 8/8 [==============================] - 25s 3s/step - loss: 0.3774 - accuracy: 0.8250 - val_loss: 0.4611 - val_accuracy: 0.7950
# Epoch 6/15
# 8/8 [==============================] - 24s 3s/step - loss: 0.4770 - accuracy: 0.7667 - val_loss: 0.7818 - val_accuracy: 0.6150
# Epoch 7/15
# 8/8 [==============================] - 24s 3s/step - loss: 0.3729 - accuracy: 0.8333 - val_loss: 0.9220 - val_accuracy: 0.5850
# 0.7950000166893005

# %%
#搜索最佳迁移率R(验证理论)

classifier_p = model.get_layer(model.layers[-1].name)
r_list = get_r_list()
best_acc = r_1_acc
r_acc = []

for i in range(len(r_list)):
    r = r_list[i]
    conv_base = tf.keras.applications.resnet50.ResNet50(weights='imagenet',include_top=False)
    classifier = classifier_p
    model = r_compiled_model()
    filepath = 'resnet50_r_{:.2f}.keras'.format(r)
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=2),
                 tf.keras.callbacks.ModelCheckpoint(filepath=filepath,
                                                    monitor='val_accuracy',
                                                    save_best_only=True)]
    history = model.fit(train_images,train_labels,
                        epochs=15,
                        validation_data=(val_images,val_labels),
                        callbacks=callbacks)
    r_acc.append(max(history.history['val_accuracy']))
    
    if i == 0 and r_acc[0] < r_1_acc:
        r_list = r_list[:1]+r_list[:0:-1]
        continue
    if r_acc[i] > best_acc:
        best_acc = r_acc[i]
# Out:
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620E9D80D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620E9D80D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8250WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000026264DA4D90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000026264DA4D90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 83s 10s/step - loss: 0.3831 - accuracy: 0.8250 - val_loss: 0.8473 - val_accuracy: 0.6150
# Epoch 2/15
# 8/8 [==============================] - 76s 10s/step - loss: 0.3590 - accuracy: 0.8542 - val_loss: 0.7792 - val_accuracy: 0.6550
# Epoch 3/15
# 8/8 [==============================] - 75s 10s/step - loss: 0.3463 - accuracy: 0.8542 - val_loss: 0.7262 - val_accuracy: 0.6800
# Epoch 4/15
# 8/8 [==============================] - 76s 10s/step - loss: 0.3312 - accuracy: 0.8792 - val_loss: 0.6885 - val_accuracy: 0.6900
# Epoch 5/15
# 8/8 [==============================] - 74s 9s/step - loss: 0.3208 - accuracy: 0.8833 - val_loss: 0.6511 - val_accuracy: 0.6900
# Epoch 6/15
# 8/8 [==============================] - 74s 9s/step - loss: 0.3065 - accuracy: 0.9083 - val_loss: 0.6267 - val_accuracy: 0.6900
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002625DB652F0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002625DB652F0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.9042WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620E9D8510> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620E9D8510> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 36s 4s/step - loss: 0.3104 - accuracy: 0.9042 - val_loss: 0.8008 - val_accuracy: 0.6500
# Epoch 2/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2974 - accuracy: 0.9042 - val_loss: 0.7506 - val_accuracy: 0.6700
# Epoch 3/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2840 - accuracy: 0.9292 - val_loss: 0.7013 - val_accuracy: 0.6800
# Epoch 4/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2890 - accuracy: 0.8958 - val_loss: 0.6684 - val_accuracy: 0.6900
# Epoch 5/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2784 - accuracy: 0.9125 - val_loss: 0.6355 - val_accuracy: 0.6950
# Epoch 6/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2677 - accuracy: 0.9292 - val_loss: 0.6094 - val_accuracy: 0.7000
# Epoch 7/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2640 - accuracy: 0.9250 - val_loss: 0.5862 - val_accuracy: 0.7100
# Epoch 8/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2597 - accuracy: 0.9333 - val_loss: 0.5688 - val_accuracy: 0.7250
# Epoch 9/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2460 - accuracy: 0.9458 - val_loss: 0.5584 - val_accuracy: 0.7300
# Epoch 10/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2386 - accuracy: 0.9583 - val_loss: 0.5511 - val_accuracy: 0.7300
# Epoch 11/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2376 - accuracy: 0.9417 - val_loss: 0.5462 - val_accuracy: 0.7400
# Epoch 12/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2278 - accuracy: 0.9458 - val_loss: 0.5389 - val_accuracy: 0.7500
# Epoch 13/15
# 8/8 [==============================] - 32s 4s/step - loss: 0.2332 - accuracy: 0.9542 - val_loss: 0.5335 - val_accuracy: 0.7600
# Epoch 14/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2169 - accuracy: 0.9583 - val_loss: 0.5272 - val_accuracy: 0.7550
# Epoch 15/15
# 8/8 [==============================] - 31s 4s/step - loss: 0.2147 - accuracy: 0.9583 - val_loss: 0.5223 - val_accuracy: 0.7600
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002625DCADC80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002625DCADC80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.3509 - accuracy: 0.8542WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000262130602F0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000262130602F0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 48s 6s/step - loss: 0.3509 - accuracy: 0.8542 - val_loss: 0.8170 - val_accuracy: 0.6600
# Epoch 2/15
# 8/8 [==============================] - 44s 6s/step - loss: 0.3320 - accuracy: 0.8792 - val_loss: 0.7717 - val_accuracy: 0.6750
# Epoch 3/15
# 8/8 [==============================] - 45s 6s/step - loss: 0.3230 - accuracy: 0.8500 - val_loss: 0.7305 - val_accuracy: 0.6850
# Epoch 4/15
# 8/8 [==============================] - 44s 6s/step - loss: 0.2988 - accuracy: 0.8917 - val_loss: 0.7049 - val_accuracy: 0.6850
# Epoch 5/15
# 8/8 [==============================] - 44s 6s/step - loss: 0.2851 - accuracy: 0.9167 - val_loss: 0.6775 - val_accuracy: 0.6900
# Epoch 6/15
# 8/8 [==============================] - 44s 6s/step - loss: 0.2923 - accuracy: 0.9000 - val_loss: 0.6539 - val_accuracy: 0.6900
# Epoch 7/15
# 8/8 [==============================] - 44s 6s/step - loss: 0.2624 - accuracy: 0.9250 - val_loss: 0.6366 - val_accuracy: 0.6900
# Epoch 1/15
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620B361B70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002620B361B70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8458WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620E9E7950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002620E9E7950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 64s 8s/step - loss: 0.3426 - accuracy: 0.8458 - val_loss: 0.8487 - val_accuracy: 0.6450
# Epoch 2/15
# 8/8 [==============================] - 58s 7s/step - loss: 0.3411 - accuracy: 0.8292 - val_loss: 0.7957 - val_accuracy: 0.6700
# Epoch 3/15
# 8/8 [==============================] - 57s 7s/step - loss: 0.3110 - accuracy: 0.8833 - val_loss: 0.7499 - val_accuracy: 0.6850
# Epoch 4/15
# 8/8 [==============================] - 57s 7s/step - loss: 0.3195 - accuracy: 0.8708 - val_loss: 0.7157 - val_accuracy: 0.6900
# Epoch 5/15
# 8/8 [==============================] - 56s 7s/step - loss: 0.2897 - accuracy: 0.8875 - val_loss: 0.6889 - val_accuracy: 0.6900
# Epoch 6/15
# 8/8 [==============================] - 57s 7s/step - loss: 0.2804 - accuracy: 0.9167 - val_loss: 0.6620 - val_accuracy: 0.6950
# Epoch 7/15
# 8/8 [==============================] - 57s 7s/step - loss: 0.2690 - accuracy: 0.9167 - val_loss: 0.6396 - val_accuracy: 0.6900
# Epoch 8/15
# 8/8 [==============================] - 56s 7s/step - loss: 0.2468 - accuracy: 0.9250 - val_loss: 0.6201 - val_accuracy: 0.6950

# %%
#观察结果

print(r_list)
print(r_acc)
# Out:
# [0, 0.8114285714285714, 0.45714285714285713, 0.21714285714285714]
# [0.6899999976158142, 0.7599999904632568, 0.6899999976158142, 0.6949999928474426]

# %%
##整理结果

r_list.pop(0)
r_0_acc = r_acc.pop(0)

r_list.append(0)
r_acc.append(r_0_acc)

r_list.insert(0,1)
r_acc.insert(0,r_1_acc)
print(r_list)
print(r_acc)
# Out:
# [1, 0.8114285714285714, 0.45714285714285713, 0.21714285714285714, 0]
# [0.7950000166893005, 0.7599999904632568, 0.6899999976158142, 0.6949999928474426, 0.6899999976158142]

# %%
#展示结果

import matplotlib.pyplot as plt
plt.figure()
plt.plot(r_list,r_acc,linestyle='-',marker='o',color='c',label='resnet50')
plt.xlabel('transfer rate')
plt.ylabel('accuracy')
plt.ylim((0.5,1))

plt.title('Validation accuracy')
plt.legend()
plt.show()
